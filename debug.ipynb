# %%
# !micromamba run -n avion python /u/dduka/work/projects/Thesis/AVION/tools/refinement/score_lavila_segment.py\
  --video /ptmp/dduka/databases/ego4d/video_320px_15sec/001e3e4e-2743-47fc-8564-d5efd11f9e90.mp4/0.mp4 \
  --start 0.1 \
  --end 2.4 \
  --caption "person opens the fridge" \
  --checkpoint /ptmp/dduka/work/training_metadata/avion/qwen3vl_full_refined_lavila_baseline/
# Out:
# 2026-05-05 14:15:40,927 INFO: resolved LaViLa checkpoint directory /raven/ptmp/dduka/work/training_metadata/avion/qwen3vl_full_refined_lavila_baseline -> /raven/ptmp/dduka/work/training_metadata/avion/qwen3vl_full_refined_lavila_baseline/checkpoint_best.pt
# 2026-05-05 14:15:41,081 INFO: initializing LaViLa scorer device=cuda precision=torch.float16 video_root=/raven/ptmp/dduka/databases/ego4d/video_320px_15sec/001e3e4e-2743-47fc-8564-d5efd11f9e90.mp4
# Traceback (most recent call last):
#   File "/raven/u/dduka/work/projects/Thesis/AVION/avion/models/model_clip.py", line 2, in <module>
#     import clip
# ModuleNotFoundError: No module named 'clip'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/u/dduka/work/projects/Thesis/AVION/tools/refinement/score_lavila_segment.py", line 268, in <module>
#     main()
# ...

# %%
import json

with open("/tmp/lavila_score.json") as f:
    result = json.load(f)

result
